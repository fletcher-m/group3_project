# %%
# import data into a dataframe

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


squirrels_df = pd.read_csv('../data/2018_Central_Park_Squirrel_Census_-_Squirrel_Data.csv', index_col='Unique Squirrel ID')
squirrels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3023 entries, 37F-PM-1014-03 to 5E-PM-1012-01
# Data columns (total 30 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           3023 non-null   float64
#  1   Y                                           3023 non-null   float64
#  2   Hectare                                     3023 non-null   object
#  3   Shift                                       3023 non-null   object
#  4   Date                                        3023 non-null   int64
#  5   Hectare Squirrel Number                     3023 non-null   int64
#  6   Age                                         2902 non-null   object
#  7   Primary Fur Color                           2968 non-null   object
#  8   Highlight Fur Color                         1937 non-null   object
# ...

# %%
squirrels_df['Date'] = pd.to_datetime(squirrels_df['Date'], format='%m%d%Y')

# %%
fig = plt.figure(figsize=(10, 6))   

colors = {'Gray': 'gray', 'Cinnamon': 'saddlebrown', 'Black': 'black'}
plt.pie(squirrels_df['Primary Fur Color'].value_counts(), labels=squirrels_df['Primary Fur Color'].value_counts().index, autopct='%1.1f%%', colors=colors.values())
# Out:
# ([<matplotlib.patches.Wedge at 0x7fae15fa49a0>,
# ...
#  [Text(-0.9524338184438234, 0.5503360986565556, 'Gray'),
#   Text(0.8868977606157182, -0.6507014386143805, 'Cinnamon'),
#   Text(1.093469009353554, -0.11968928767169311, 'Black')],
#  [Text(-0.5195093555148127, 0.3001833265399394, '83.3%'),
#   Text(0.4837624148813008, -0.3549280574260257, '13.2%'),
#   Text(0.5964376414655749, -0.06528506600274168, '3.5%')])

# %%
squirrels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3023 entries, 37F-PM-1014-03 to 5E-PM-1012-01
# Data columns (total 30 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           3023 non-null   float64
#  1   Y                                           3023 non-null   float64
#  2   Hectare                                     3023 non-null   object
#  3   Shift                                       3023 non-null   object
#  4   Date                                        3023 non-null   datetime64[ns]
#  5   Hectare Squirrel Number                     3023 non-null   int64
#  6   Age                                         2902 non-null   object
#  7   Primary Fur Color                           2968 non-null   object
#  8   Highlight Fur Color                         1937 non-null   object
# ...

# %%
squirrels_df.head()
#squirrels_df.describe()
# Out:
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.968857  40.783783     21B-AM-1019-04     21B    AM  10192018
# 2 -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3 -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4 -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
#
#    Hectare Squirrel Number    Age Primary Fur Color Highlight Fur Color  ...  \
# 0                        3    NaN               NaN                 NaN  ...
# 1                        4    NaN               NaN                 NaN  ...
# 2                        8    NaN              Gray                 NaN  ...
# 3                       14  Adult              Gray                 NaN  ...
# 4                        5  Adult              Gray            Cinnamon  ...
#
#     Kuks  Quaas  Moans Tail flags Tail twitches  Approaches  Indifferent  \
# ...
