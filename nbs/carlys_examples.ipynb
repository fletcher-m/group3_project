# %%
from bs4 import BeautifulSoup
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
import requests
URL = "https://worldpopulationreview.com/state-rankings/happiest-states"
r = requests.get(URL)
print(r.content)
# Out:
# b'<!DOCTYPE html><html><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta http-equiv="Content-Security-Policy" content="block-all-mixed-content"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"Organization","url":"https://www.worldpopulationreview.com","name":"World Population Review"}</script><title>Happiest States [Updated June 2023]</title><link rel="preload" as="image" imageSrcSet="/_next/image?url=%2Fsvg_placeholder.png&amp;w=1080&amp;q=75 1x, /_next/image?url=%2Fsvg_placeholder.png&amp;w=2048&amp;q=75 2x" fetchpriority="high"/><meta name="next-head-count" content="6"/><link rel="preload" href="/_next/static/css/73e9691e0147adff.css" as="style"/><link rel="stylesheet" href="/_next/static/css/73e9691e0147adff.css" data-n-g=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-78c92fac7aa8fdd8.js"></script><script defer="" src="/_next/static/chunks/9
# ...

# %% [markdown]
# The above piece of code states:
# -First of all import the requests library.
# -Then, specify the URL of the webpage you want to scrape.
# -Send a HTTP request to the specified URL and save the response from server in a response object called r.
# -Now, as print r.content to get the raw HTML content of the webpage. It is of ‘string’ type.

# %% [markdown]
# # Extracting the Title of a Wikipedia Page:

# %%
# Replace this with the URL of the webpage you want to scrape
url = 'https://en.wikipedia.org/wiki/2020_United_States_census'


# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content using Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the title tag and print its text
    title_tag = soup.title
    if title_tag:
        print('Title:', title_tag.text)
    else:
        print('No title found on the page.')
else:
    print('Failed to retrieve the web page.')
# Out:
# Title: 2020 United States census - Wikipedia

# %% [markdown]
# # Get the Anchor Tags From a Webpage

# %%
# Replace 'url' with the URL of the webpage you want to scrape
url = 'https://en.wikipedia.org/wiki/2020_United_States_census'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # The HTML content of the webpage is in response.text
    html_content = response.text

    # Create a BeautifulSoup object
    soup = BeautifulSoup(html_content, 'html.parser')

    # Extract all links (anchor tags) from the webpage
    links = soup.find_all('a')
    
    # Print the href attribute of each link
    for link in links:
        print(link.get('href'))
else:
    print('Failed to retrieve the web page.')
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=2020+United+States+census
# /w/index.php?title=Special:UserLogin&returnto=2020+United+States+census
# /w/index.php?title=Special:CreateAccount&returnto=2020+United+States+census
# /w/index.php?title=Special:UserLogin&returnto=2020+United+States+census
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Background
# #Purpose
# #Reapportionment
# #Redistricting
# ...

# %%
# Replace 'url' with the URL of the webpage you want to scrape
url = 'https://en.wikipedia.org/wiki/2020_United_States_census'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # The HTML content of the webpage is in response.text
    html_content = response.text
    
# Find the main content div
content_div = soup.find(id='content')

# Extract the text from the content div
page_text = content_div.get_text()

# Print or process the extracted text as needed
print(page_text)
# Out:
# Toggle the table of contents
#
#
#
#
#
# Toggle the table of contents
#
#
#
#
#
#
#
# 2020 United States census
#
#
#
# 26 languages
#
#
#
#
# العربيةCatalàDeutschΕλληνικάEspañolفارسیFrançais한국어Bahasa IndonesiaItalianoLietuviųMagyarBahasa MelayuNederlandsپنجابیPortuguêsRomânăРусскийSimple EnglishSuomiSvenskaไทยУкраїнськаاردوTiếng Việt中文
#
# Edit links
#
#
#
#
#
#
#
#
#
#
#
# ArticleTalk
#
#
#
#
#
# English
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ReadEditView history
#
#
#
#
#
#
#
# Tools
#
#
#
#
#
# Tools
# move to sidebar
# hide
#
#
#
# 		Actions
#
#
#
# ReadEditView history
#
#
#
#
#
# 		General
#
#
#
# What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageWikidata item
#
#
#
#
#
# 		Print/export
#
#
#
# Download as PDFPrintable version
#
#
#
#
#
# 		In other projects
#
#
#
# Wikimedia Commons
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# From Wikipedia, the free encyclopedia
#
#
# 24th U.S. decennial census
#
#
# ...

# %%
# Find all tables on the page
tables = soup.find_all('table')

# Iterate through the tables and extract data
for table in tables:
    # Process and extract data from each table
    # Example: Extract table rows and cells
    rows = table.find_all('tr')
    for row in rows:
        cells = row.find_all('td')
        for cell in cells:
            print(cell.get_text())
# Out:
# ← 2010
# April 1, 2020
# 2030 →
#
#
# ← 2010
# April 1, 2020
# 2030 →
# ← 2010
# April 1, 2020
# 2030 →
# Seal of the U.S. Census Bureau
#
# United States
#
# Census topics
#  People and population
# Race and ethnicity
# Families and living arrangements
# Health
# Education
# Business and economy
# Employment
# Housing
# Income and poverty
#
#
# U.S. Census Bureau
# www.census.gov
# 331,449,281 ( 7.4%)
# California (39,538,223)
# Wyoming (576,851)
# ← 2010
# April 1, 2020
# 2030 →
# 1
#
#  California
# 39,538,223
# 37,253,956
# 2,284,267
# 6.1%
#
# 2
#
#  Texas
# 29,145,505
# 25,145,561
# 3,999,944
# 15.9%
#
# 3
#
#  Florida
# 21,538,187
# 18,801,310
# 2,736,877
# 14.6%
#
# 4
#
#  New York
# 20,201,249
# 19,378,102
# 823,147
# 4.3%
#
# 5
#
#  Pennsylvania
# 13,002,700
# 12,702,379
# 300,321
# 2.4%
#
# 6
#
#  Illinois
# 12,812,508
# 12,830,632
# −18,124
# −0.1%
#
# 7
#
#  Ohio
# 11,799,448
# 11,536,504
# 262,944
# 2.3%
#
# 8
#
#  Georgia
# 10,711,908
# 9,687,653
# 1,024,255
# 10.6%
#
# ...

# %%
lists = soup.find_all(['ul', 'ol'])

# Iterate through the lists and extract list items
for lst in lists:
    list_items = lst.find_all('li')
    for item in list_items:
        print(item.get_text())
# Out:
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# Donate
# Help
# Learn to edit
# Community portal
# Recent changes
# Upload file
# Create account
# Log in
#  Create account
#  Log in
# Contributions
# Talk
#
#
# (Top)
#
#
#
#
#
# 1Background
#
#
#
#
#
#
#
# 2Purpose
#
#
#
# Toggle Purpose subsection
#
#
#
#
#
# 2.1Reapportionment
#
#
#
#
#
#
#
# 2.2Redistricting
#
#
#
#
#
#
#
# 2.3Federal funding distribution
#
#
#
#
#
#
#
#
#
# 2.1Reapportionment
#
#
#
#
#
#
#
# 2.2Redistricting
#
#
#
#
#
#
#
# 2.3Federal funding distribution
#
#
#
#
#
#
#
# 3Major design changes
#
#
#
#
#
#
#
# 4Questions and data uses
#
#
#
#
#
#
#
# 5Timeline
#
#
#
#
#
#
#
# 6Response rates
#
#
#
#
#
#
#
# 7Marketing and partnerships
#
#
#
#
#
#
#
# 8Implementation problems
#
#
#
#
#
#
#
# 9COVID-19 pandemic emergency
#
#
#
#
#
#
#
# 10State rankings
#
#
#
#
#
#
#
# 11City rankings
#
#
#
#
#
#
#
# 12Citizenship question debate
#
#
#
# ...

# %%
# Find all links on the page
links = soup.find_all('a')

# Extract and print the href attribute of each link
for link in links:
    href = link.get('href')
    print(href)
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=2020+United+States+census
# /w/index.php?title=Special:UserLogin&returnto=2020+United+States+census
# /w/index.php?title=Special:CreateAccount&returnto=2020+United+States+census
# /w/index.php?title=Special:UserLogin&returnto=2020+United+States+census
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Background
# #Purpose
# #Reapportionment
# #Redistricting
# ...

# %%
# Define the URL of the Wikipedia page
url = 'https://en.wikipedia.org/wiki/Vermont'

# Send an HTTP GET request to the URL
response = requests.get(url)

if response.status_code == 200:
    html_content = response.text
else:
    print('Failed to retrieve the Wikipedia page.')
    exit()

# Create a Beautiful Soup object
soup = BeautifulSoup(html_content, 'html.parser')

# Find all tables in the content
tables = soup.find_all('table')

# Check if the fourth table exists (Population by Race table)
if len(tables) > 3:
    table = tables[3]
else:
    print('Population by Race table not found on the page.')
    exit()

# Parse and process the table data
if table:
    rows = table.find_all('tr')
    for row in rows:
        cells = row.find_all(['td', 'th'])
        row_data = [cell.get_text(strip=True) for cell in cells]
        print(row_data)

# %%
# Parse the table data and store it in a list of lists
table_data = []
if table:
    rows = table.find_all('tr')
    for row in rows:
        cells = row.find_all(['td', 'th'])
        row_data = [cell.get_text(strip=True) for cell in cells]
        table_data.append(row_data)

# Convert the list of lists into a Pandas DataFrame
df = pd.DataFrame(table_data[1:], columns=table_data[0])

# Print the DataFrame
print(df)
# Out:
#              Town Population
# 0           Essex     22,094
# 1      Colchester     17,524
# 2      Bennington     15,333
# 3     Brattleboro     12,184
# 4          Milton     10,723
# 5        Hartford     10,686
# 6       Williston     10,103
# 7      Middlebury      9,152
# 8     Springfield      9,062
# 9           Barre      7,923
# 10      Shelburne      7,717
# 11  St. Johnsbury      7,364

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Town'], df['Population'], color='skyblue')
plt.ylabel('Population')
plt.title('Population of Vermont by Town')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.gca().invert_yaxis()


# Display the chart
plt.show()

# %% [markdown]
# # Beautiful Soup Tutorial
#
# -insert image-
#
# ## Brief Description:
#
#
#
# ### What is Beautiful Soup?
# A library for parsing HTML and web scraping. Leonard Richardson initially released in 2004. The last updated version (4) released April 2023.
#
#
#
#
# ### Why Beautiful Soup?
# Beautiful Soup provides a way to transform HTML documents into specific python objects. This can be helpful for navigating, searching, and modifying data from the web.
#
# -insert more text here-
# -insert text about why its bettter than scrappy-
#
# To Note: Web scraping can be risky depending on privacy policies of pages. Make sure to read the details of each websites policies prior to scrubbing the data. You can check the robots.txt file on a website to determine if the data is publically accessible.
#
#
#
# ### Installation Instructions:
# 1. Run this in terminal:
# ```python
#     pip install beautifulsoup4
# ```
#
# 2. Add this import to the top of your code
# ```python
#     from bs4 import BeautifulSoup
# ``````
# Note on Dependencies:
# -Use the beautiful_group_3 environment
#
# -Should we add other steps

# %% [markdown]
# ## Key Functions within Beautiful Soup
# #### get the title of a page
# print(soup.title)
#
# #### get attributes of the page:
# print(soup.title.name)
#
# #### get text values on the page:
# print(soup.title.string)
#
# #### beginning navigation:
# print(soup.title.parent.name)
#
# #### getting specific values:
# print(soup.p)
#
# #### get anchor tags on the page:
#
# #### get tables from the page:
#
#
# ### Tutorial
# -insert Oksana's tutorial video here-
# -insert code chunks for parsing data into a dataframe-

# %% [markdown]
# Example:

# %%
#Import Libraries Needed
from bs4 import BeautifulSoup
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Define the URL of the Wikipedia page
url = 'https://en.wikipedia.org/wiki/Vermont'

# Send an HTTP GET request to the URL
response = requests.get(url)

if response.status_code == 200:
    html_content = response.text
else:
    print('Failed to retrieve the Wikipedia page.')
    exit()

# Create a Beautiful Soup object
soup = BeautifulSoup(html_content, 'html.parser')

# Find all tables in the content
tables = soup.find_all('table')

# Check if the fourth table exists (Population by Race table)
if len(tables) > 3:
    table = tables[3]
else:
    print('Population by Race table not found on the page.')
    exit()

# Parse and process the table data
if table:
    rows = table.find_all('tr')
    for row in rows:
        cells = row.find_all(['td', 'th'])
        row_data = [cell.get_text(strip=True) for cell in cells]
        print(row_data)

# %%
#Get the data into a structured format: 
# Parse the table data and store it in a list of lists
table_data = []
if table:
    rows = table.find_all('tr')
    for row in rows:
        cells = row.find_all(['td', 'th'])
        row_data = [cell.get_text(strip=True) for cell in cells]
        table_data.append(row_data)

# Convert the list of lists into a Pandas DataFrame
df = pd.DataFrame(table_data[1:], columns=table_data[0])

# Print the DataFrame
print(df)

# %%
#Plot the data: 
plt.figure(figsize=(10, 6))
plt.bar(df['Town'], df['Population'], color='skyblue')
plt.ylabel('Population')
plt.title('Population of Vermont by Town')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.gca().invert_yaxis()


# Display the chart
plt.show()

# %% [markdown]
# ### Potential Use in Environmental Data Science:
# >A tool to access data not in a csv format and on a webpage
# >Increasing the accessibility to data given we can access many types of data structures via the web
# >Data that exists on webpages includes: government websites, DataONE xml files, data in shiny apps
#
#
# ### Limitations & Permissioning:
# Compare to scrapy

# %% [markdown]
# ### Resources:
# Project is located here:
# https://github.com/fletcher-m/group3_project
#
# About Beautiful Soup: -insert website -
#
# Tutorial: -insert website-
#
# Beautiful Soup Github: -insert website-
#
# -list any other sources-

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the webpage
url = 'https://bren.ucsb.edu/people/masters-students#meds-class-of-2024'

# Send an HTTP GET request to the URL
response = requests.get(url)

if response.status_code == 200:
    html_content = response.text
else:
    print('Failed to retrieve the webpage.')
    exit()

# Create a Beautiful Soup object
soup = BeautifulSoup(html_content, 'html.parser')

# Find the unordered list with class "staff_list"
name_list = soup.find('ul', class_='staff_list')

# Extract and print the names
if name_list:
    names = [item.get_text() for item in name_list.find_all('li')]
    for name in names:
        print(name)

# %%
import requests

# Define the URL of the Indeed job search results page
url = 'https://www.indeed.com/q-environmental-data-science-jobs.html?vjk=e8af4e58a6a480af'

try:
    # Send an HTTP GET request to the URL
    user_agent = "Mozilla/5.0 (X11; Linux x86_64; rv:78.0) Gecko/20100101 Firefox/78.0"
    headers = {"User-Agent": user_agent}
    response = requests.get(url, headers=headers)
    print(response.status_code)
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        html_content = response.text
    else:
        print(f'Failed to retrieve the Indeed job search results page. Status Code: {response.status_code}')

except requests.RequestException as e:
    # Handle the exception and provide information
    print(f'An error occurred during the HTTP request: {str(e)}')

except MemoryError as mem_error:
    # Handle a MemoryError if it occurs
    print(f'MemoryError occurred: {str(mem_error)}')

except Exception as e:
    # Handle other exceptions
    print(f'An unexpected error occurred: {str(e)}')

# Check if the HTML content was successfully retrieved
if 'html_content' in locals():
    print('HTML content successfully retrieved.')
else:
    print('HTML content not available.')

# Continue with processing the HTML content if available

soup = BeautifulSoup(html_content, 'html.parser')

# Find and extract job titles based on the CSS selector
job_titles = [element.get_text() for element in soup.select('.jobTitle')]

# Print or process the job titles
for job_title in job_titles:
    print(job_title)
# Out:
# 403
# Failed to retrieve the Indeed job search results page. Status Code: 403
# HTML content successfully retrieved.

# %%
import requests

# Define a URL for a test website that echoes the User-Agent header
url = 'https://httpbin.org/user-agent'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response to get the User-Agent string
    user_agent = response.json()['user-agent']
    print(f'Your User-Agent string is: {user_agent}')
else:
    print(f'Failed to retrieve the User-Agent string. Status Code: {response.status_code}')
# Out:
# Your User-Agent string is: python-requests/2.31.0

# %%
url = 'https://www.indeed.com/q-environmental-data-science-jobs.html?vjk=e8af4e58a6a480af'
user_agent = "Chrome/115.0.0.0"
headers = {"User-Agent": user_agent}
response = requests.get(url, headers=headers)
print(response.status_code)
# Out:
# 403

# %%
url = 'https://www.usharbors.com/harbor/california/santa-barbara-ca/tides/'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the HTML elements containing the tide text based on the HTML structure (you need to inspect the page)
    tide_elements = soup.find_all('p', class_='js picture csscalc no-touchevents no-cssvhunit cssvminunit cssvmaxunit cssvwunit objectfit object-fit csscolumns csscolumns-width csscolumns-span csscolumns-fill csscolumns-gap csscolumns-rule csscolumns-rulecolor csscolumns-rulestyle csscolumns-rulewidth csscolumns-breakbefore csscolumns-breakafter csscolumns-breakinside no-cssgridlegacy cssgrid flexbox flexboxlegacy no-flexboxtweener flexwrap wf-roboto-n4-active wf-active')  # Replace 'your-tide-text-class' with the actual class name
    
    # Loop through the tide elements and extract the text
    for element in tide_elements:
        tide_text = element.get_text().strip()  # Get and clean the text
        print(tide_text)
else:
    print(f'Failed to retrieve the tide information page. Status Code: {response.status_code}')
# Out:
# Failed to retrieve the tide information page. Status Code: 403

# %%
# Define the URL of the stock data page
url = 'https://finance.yahoo.com/calendar/'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the HTML elements containing the stock data based on the HTML structure (you need to inspect the page)
    stock_tables = soup.find_all('table', class_='data-reactroot')  # Replace 'your-stock-table-class' with the actual class name
    
    # Loop through the stock tables and extract the data
    for table in stock_tables:
        rows = table.find_all('tr')
        for row in rows:
            columns = row.find_all('td')
            for column in columns:
                # Extract and print the stock data or store it in a data structure
                print(column.get_text().strip())  # Adjust as needed
else:
    print(f'Failed to retrieve the stock data page. Status Code: {response.status_code}')
# Out:
# Failed to retrieve the stock data page. Status Code: 404

# %%
# Define the URL of the web page
url = 'https://finance.yahoo.com/news/yahoo-finance-chartbook-50-charts-markets-and-economy-right-now-100006007.html'

# Send an HTTP GET request to the URL
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
etf_elements = soup.find_all('ul', class_='your-etf-list-class')  # Replace 'your-etf-list-class' with the actual class name
#for element in etf_elements:
 #       # Extract and print the ETF data or store it in a data structure
  #      etf_data = element.get_text().strip()  # Get and clean the text
   #     print(etf_data)
#else:
 #   print(f'Failed to retrieve the web page. Status Code: {response.status_code}')

# %%
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the HTML elements containing the ETF data based on the HTML structure (you need to inspect the page)
    etf_elements = soup.find_all('ul', class_='your-etf-list-class')  # Replace 'your-etf-list-class' with the actual class name
    
    # Loop through the ETF elements and extract the data
    for element in etf_elements:
        # Extract and print the ETF data or store it in a data structure
        etf_data = element.get_text().strip()  # Get and clean the text
        print(etf_data)
else:
    print(f'Failed to retrieve the web page. Status Code: {response.status_code}')

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt


# Define the URL of the Wikipedia page
url = 'https://en.wikipedia.org/wiki/List_of_California_wildfires'

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the wildfire data table based on the HTML structure (you need to inspect the page)
    table = soup.find('table', {'class': 'wikitable'})  # Assuming the table has 'wikitable' class
    
# Check if the table was found
    if table:
        # Initialize lists to store data
        headers = []
        rows = []
        
        # Extract table headers
        header_row = table.find('tr')
        header_columns = header_row.find_all('th')
        headers = [column.get_text().strip() for column in header_columns]
        
        # Extract table data
        data_rows = table.find_all('tr')[1:]  # Skip the header row
        for row in data_rows:
            columns = row.find_all('td')
            row_data = [column.get_text().strip() for column in columns]
            rows.append(row_data)
        
        # Create a DataFrame from the extracted data
        df = pd.DataFrame(rows, columns=headers)
        
        # Display the DataFrame
        print(df)
    else:
        print('Wildfire data table not found on the page.')
else:
    print(f'Failed to retrieve the Wikipedia page. Status Code: {response.status_code}')
# Out:
#               Year  Fires      Acres   Hectares           Ref
# 0             2000  7,622    295,026    119,393          [12]
# 1             2001  9,458    329,126    133,193          [13]
# 2             2002  8,328    969,890    392,500      [14][15]
# 3             2003  9,116  1,020,460    412,970  [16][17][18]
# 4             2004  8,415    264,988    107,237      [19][20]
# 5             2005  7,162    222,538     90,058      [21][22]
# 6             2006  8,202    736,022    297,858      [23][24]
# 7             2007  9,093  1,520,362    615,269      [12][25]
# 8             2008  6,255  1,593,690    644,940          [12]
# 9             2009  9,159    422,147    170,837      [26][27]
# 10            2010  6,554    109,529     44,325          [28]
# 11            2011  7,989    168,545     68,208      [29][30]
# 12            2012  7,950    869,599    351,914          [31]
# 13            2013  9,907    601,635    243,473      [32][33]
# ...

# %%
# Sort the DataFrame by acres burned in descending order
df = df.sort_values(by='Acres', ascending=False)
        
# Create a bar plot of the top wildfires by acres burned
plt.figure(figsize=(10, 6))
plt.barh(df['Year'], df['Acres'], color='blue')
plt.xlabel('Acres burned')
plt.ylabel('Year')
plt.title('California Wildfire Acreage Burned per Year')
plt.gca().invert_yaxis()  # Reverse the order to show the largest first
plt.xticks(rotation=45, ha='right')
plt.show()
